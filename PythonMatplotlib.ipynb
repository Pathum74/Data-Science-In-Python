# %%
import matplotlib.pyplot as plt
import numpy as nm
import pandas as pd

# %%
data=pd.read_csv('srilanka covid data.csv')
data.describe()
# Out:
#         time line    total_cases    new_cases  new_cases_smoothed  \
# count  461.000000     461.000000   461.000000          456.000000
# mean   231.000000   25275.407809   238.312364          230.790090
# std    133.223496   34311.244210   311.024985          282.873668
# min      1.000000       1.000000     0.000000            0.000000
# 25%    116.000000    1055.000000     6.000000            7.857000
# 50%    231.000000    3234.000000    35.000000           39.285500
# 75%    346.000000   46248.000000   459.000000          450.786000
# max    461.000000  109862.000000  1716.000000         1325.143000
#
#        total_deaths  new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count    400.000000   400.00000           456.000000               461.000000
# mean     159.842500     1.71750             1.448325              1180.363024
# std      211.899921     2.67218             1.904914              1602.337048
# ...

# %%
data.dtypes
# Out:
# iso_code                                  object
# continent                                 object
# location                                  object
# date                                      object
# time line                                  int64
# total_cases                                int64
# new_cases                                  int64
# new_cases_smoothed                       float64
# total_deaths                             float64
# new_deaths                               float64
# new_deaths_smoothed                      float64
# total_cases_per_million                  float64
# new_cases_per_million                    float64
# new_cases_smoothed_per_million           float64
# total_deaths_per_million                 float64
# new_deaths_per_million                   float64
# new_deaths_smoothed_per_million          float64
# reproduction_rate                        float64
# icu_patients                             float64
# ...

# %% [markdown]
# Two ways to create matplotlib plot
# 1.Funtional approach - use command

# %%
plt.plot(data['time line'],data['total_cases'])

# %% [markdown]
# 2.Object orianted interface - creating a figure object and with in figure

# %%
fig=plt.figure()
ax1=fig.add_axes([0.5,0.2,1,1])

ax1.plot(data['time line'],data['total_cases'])

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,3,1])
ax.plot(data['time line'],data['total_cases'])

# %%
fig,ax=plt.subplots()
ax.plot(data['time line'],data['total_cases'],label='total cases')
ax.set_xlabel('time line')
ax.set_ylabel('total cases')
ax.set_title('Covid Cumalative')
ax.legend(loc='best')
